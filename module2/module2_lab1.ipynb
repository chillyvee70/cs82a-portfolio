# %%
name = 'Anna'
hourly_wage = 10
hours = 40

# %%
float(hourly_wage)
int(hours)
# Out:
# 40

# %%
weekly_pay = hourly_wage * hours
print(f"{name} earns {weekly_pay} per week")
# Out:
# Anna earns 400 per week

# %%
temps = [61, 65, 72, 58, 70, 74, 68]
high = 0
for s in temps:
    if s > 65:
        high = high + 1
print(high)
# Out:
# 4

# %%
def to_celsius(f):
    return (f - 32) * 5/9

print(round(to_celsius(temps[0]), 1))
# Out:
# 16.1

# %%
movie = {"title": "Dune", "year": 1965, "rating": 10}
for key, value in movie.items():
    print(key, ":", value)
# Out:
# title : Dune
# year : 1965
# rating : 10

# %%
import pandas as pd
df = pd.read_csv("chickwts1.csv")
df.head()
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean

# %%
df.shape
# Out:
# (71, 2)

# %%
df.describe()
# Out:
#            weight
# count   71.000000
# mean   261.309859
# std     78.073700
# min    108.000000
# 25%    204.500000
# 50%    258.000000
# 75%    323.500000
# max    423.000000

# %% [markdown]
# what does the describe() output tell you about chick weights (typical weight, spread, anything surprising)?
#
# The typcal weight is relatively high as indicated by the mean and 50% and 75% percentile relatively high values. The spread is wide as indicated by the std deviation. It is suprising that across all feed samples that the weight is hgiher than the avereage value. Wigh a low weight of 108 in the sample, most of the population experienced significant weight gain.

# %% [markdown]
# https://github.com/chillyvee70/cs82a-portfolio/tree/main
